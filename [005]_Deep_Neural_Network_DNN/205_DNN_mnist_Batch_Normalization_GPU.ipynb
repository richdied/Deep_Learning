# %% [markdown]
# # MNIST - Categorical Classification
# > # Batch Normalization

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  * 활성화 함수의 입력값을 정규화 과정을 수행하여 전달
#  * Gradient Vanishing 문제 해결 및 더 큰 Learning Rate를 사용 가능

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, input_shape=(28 * 28,)))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(256))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 538,890
# Trainable params: 537,354
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 6분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 8s 8ms/step - loss: 0.1808 - accuracy: 0.9449 - val_loss: 0.1023 - val_accuracy: 0.9687
# Epoch 2/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0729 - accuracy: 0.9774 - val_loss: 0.1042 - val_accuracy: 0.9697
# Epoch 3/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0458 - accuracy: 0.9854 - val_loss: 0.0941 - val_accuracy: 0.9747
# Epoch 4/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0328 - accuracy: 0.9896 - val_loss: 0.0965 - val_accuracy: 0.9732
# Epoch 5/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.1044 - val_accuracy: 0.9737
# Epoch 6/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.1052 - val_accuracy: 0.9743
# Epoch 7/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0830 - val_accuracy: 0.9801
# Epoch 8/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.1077 - val_accuracy: 0.9770
# Epoch 9/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0970 - val_accuracy: 0.9791
# Epoch 10/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0959 - val_accuracy: 0.9795
# Epoch 11/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0992 - val_accuracy: 0.9793
# Epoch 12/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0932 - val_accuracy: 0.9797
# Epoch 13/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0939 - val_accuracy: 0.9805
# Epoch 14/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.1057 - val_accuracy: 0.9797
# Epoch 15/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.1101 - val_accuracy: 0.9808
# Epoch 16/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.1009 - val_accuracy: 0.9805
# Epoch 17/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1140 - val_accuracy: 0.9800
# Epoch 18/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.1122 - val_accuracy: 0.9811
# Epoch 19/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.1132 - val_accuracy: 0.9799
# Epoch 20/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1163 - val_accuracy: 0.9815
# Epoch 21/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1080 - val_accuracy: 0.9818
# Epoch 22/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.1100 - val_accuracy: 0.9827
# Epoch 23/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.1107 - val_accuracy: 0.9815
# Epoch 24/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1138 - val_accuracy: 0.9822
# Epoch 25/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.1280 - val_accuracy: 0.9790
# Epoch 26/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.1245 - val_accuracy: 0.9808
# Epoch 27/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.1283 - val_accuracy: 0.9801
# Epoch 28/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1096 - val_accuracy: 0.9822
# Epoch 29/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1313 - val_accuracy: 0.9804
# Epoch 30/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1336 - val_accuracy: 0.9810
# Epoch 31/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.1166 - val_accuracy: 0.9822
# Epoch 32/100
# 375/375 [==============================] - 3s 9ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1348 - val_accuracy: 0.9811
# Epoch 33/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1338 - val_accuracy: 0.9815
# Epoch 34/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1285 - val_accuracy: 0.9811
# Epoch 35/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1293 - val_accuracy: 0.9822
# Epoch 36/100
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1424 - val_accuracy: 0.9797
# Epoch 37/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1697 - val_accuracy: 0.9778
# Epoch 38/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1571 - val_accuracy: 0.9798
# Epoch 39/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.1765 - val_accuracy: 0.9779
# Epoch 40/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1541 - val_accuracy: 0.9818
# Epoch 41/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1474 - val_accuracy: 0.9812
# Epoch 42/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1534 - val_accuracy: 0.9797
# Epoch 43/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.1443 - val_accuracy: 0.9806
# Epoch 44/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.1717 - val_accuracy: 0.9792
# Epoch 45/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.1520 - val_accuracy: 0.9800
# Epoch 46/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1474 - val_accuracy: 0.9809
# Epoch 47/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.1550 - val_accuracy: 0.9815
# Epoch 48/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.6633e-04 - accuracy: 0.9996 - val_loss: 0.1568 - val_accuracy: 0.9818
# Epoch 49/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1598 - val_accuracy: 0.9802
# Epoch 50/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1516 - val_accuracy: 0.9813
# Epoch 51/100
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1645 - val_accuracy: 0.9812
# Epoch 52/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1758 - val_accuracy: 0.9803
# Epoch 53/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.5094e-04 - accuracy: 0.9996 - val_loss: 0.1568 - val_accuracy: 0.9826
# Epoch 54/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1537 - val_accuracy: 0.9811
# Epoch 55/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.1590 - val_accuracy: 0.9815
# Epoch 56/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.1698e-04 - accuracy: 0.9996 - val_loss: 0.1531 - val_accuracy: 0.9808
# Epoch 57/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1468 - val_accuracy: 0.9819
# Epoch 58/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1575 - val_accuracy: 0.9815
# Epoch 59/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.3757e-04 - accuracy: 0.9997 - val_loss: 0.1677 - val_accuracy: 0.9818
# Epoch 60/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1480 - val_accuracy: 0.9821
# Epoch 61/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.2498e-04 - accuracy: 0.9996 - val_loss: 0.1784 - val_accuracy: 0.9824
# Epoch 62/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.2630e-04 - accuracy: 0.9998 - val_loss: 0.1763 - val_accuracy: 0.9809
# Epoch 63/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1742 - val_accuracy: 0.9822
# Epoch 64/100
# 375/375 [==============================] - 3s 7ms/step - loss: 8.4649e-04 - accuracy: 0.9997 - val_loss: 0.1815 - val_accuracy: 0.9806
# Epoch 65/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1818 - val_accuracy: 0.9814
# Epoch 66/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.2634e-04 - accuracy: 0.9996 - val_loss: 0.1671 - val_accuracy: 0.9808
# Epoch 67/100
# 375/375 [==============================] - 3s 7ms/step - loss: 5.4679e-04 - accuracy: 0.9998 - val_loss: 0.1735 - val_accuracy: 0.9807
# Epoch 68/100
# 375/375 [==============================] - 3s 7ms/step - loss: 7.5200e-04 - accuracy: 0.9998 - val_loss: 0.1687 - val_accuracy: 0.9813
# Epoch 69/100
# 375/375 [==============================] - 3s 7ms/step - loss: 3.7414e-04 - accuracy: 0.9999 - val_loss: 0.1816 - val_accuracy: 0.9793
# Epoch 70/100
# 375/375 [==============================] - 3s 7ms/step - loss: 7.6580e-04 - accuracy: 0.9997 - val_loss: 0.1782 - val_accuracy: 0.9806
# Epoch 71/100
# 375/375 [==============================] - 3s 7ms/step - loss: 6.0621e-04 - accuracy: 0.9998 - val_loss: 0.2064 - val_accuracy: 0.9797
# Epoch 72/100
# 375/375 [==============================] - 3s 7ms/step - loss: 4.6798e-04 - accuracy: 0.9998 - val_loss: 0.1766 - val_accuracy: 0.9805
# Epoch 73/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1757 - val_accuracy: 0.9814
# Epoch 74/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.2154e-04 - accuracy: 0.9999 - val_loss: 0.1828 - val_accuracy: 0.9806
# Epoch 75/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1870 - val_accuracy: 0.9818
# Epoch 76/100
# 375/375 [==============================] - 3s 7ms/step - loss: 8.9984e-04 - accuracy: 0.9998 - val_loss: 0.1858 - val_accuracy: 0.9799
# Epoch 77/100
# 375/375 [==============================] - 3s 7ms/step - loss: 7.6729e-04 - accuracy: 0.9997 - val_loss: 0.1836 - val_accuracy: 0.9820
# Epoch 78/100
# 375/375 [==============================] - 3s 7ms/step - loss: 6.9000e-04 - accuracy: 0.9998 - val_loss: 0.1910 - val_accuracy: 0.9817
# Epoch 79/100
# 375/375 [==============================] - 3s 7ms/step - loss: 6.3925e-04 - accuracy: 0.9998 - val_loss: 0.1893 - val_accuracy: 0.9808
# Epoch 80/100
# 375/375 [==============================] - 3s 7ms/step - loss: 7.6167e-04 - accuracy: 0.9998 - val_loss: 0.1924 - val_accuracy: 0.9807
# Epoch 81/100
# 375/375 [==============================] - 3s 7ms/step - loss: 9.9828e-04 - accuracy: 0.9997 - val_loss: 0.1927 - val_accuracy: 0.9814
# Epoch 82/100
# 375/375 [==============================] - 3s 7ms/step - loss: 6.7035e-04 - accuracy: 0.9997 - val_loss: 0.1834 - val_accuracy: 0.9821
# Epoch 83/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1858 - val_accuracy: 0.9814
# Epoch 84/100
# 375/375 [==============================] - 3s 7ms/step - loss: 8.3926e-04 - accuracy: 0.9998 - val_loss: 0.1848 - val_accuracy: 0.9816
# Epoch 85/100
# 375/375 [==============================] - 3s 7ms/step - loss: 6.1176e-04 - accuracy: 0.9998 - val_loss: 0.1928 - val_accuracy: 0.9807
# Epoch 86/100
# 375/375 [==============================] - 3s 7ms/step - loss: 3.7997e-04 - accuracy: 0.9999 - val_loss: 0.1780 - val_accuracy: 0.9810
# Epoch 87/100
# 375/375 [==============================] - 3s 7ms/step - loss: 2.9039e-04 - accuracy: 0.9999 - val_loss: 0.1881 - val_accuracy: 0.9827
# Epoch 88/100
# 375/375 [==============================] - 3s 7ms/step - loss: 5.2008e-04 - accuracy: 0.9998 - val_loss: 0.1939 - val_accuracy: 0.9800
# Epoch 89/100
# 375/375 [==============================] - 3s 7ms/step - loss: 3.6474e-04 - accuracy: 0.9998 - val_loss: 0.1913 - val_accuracy: 0.9830
# Epoch 90/100
# 375/375 [==============================] - 3s 7ms/step - loss: 2.6831e-04 - accuracy: 0.9999 - val_loss: 0.1895 - val_accuracy: 0.9833
# Epoch 91/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1874 - val_accuracy: 0.9821
# Epoch 92/100
# 375/375 [==============================] - 3s 7ms/step - loss: 3.5441e-04 - accuracy: 0.9999 - val_loss: 0.1824 - val_accuracy: 0.9828
# Epoch 93/100
# 375/375 [==============================] - 3s 7ms/step - loss: 6.5847e-04 - accuracy: 0.9998 - val_loss: 0.2107 - val_accuracy: 0.9798
# Epoch 94/100
# 375/375 [==============================] - 3s 7ms/step - loss: 4.6766e-04 - accuracy: 0.9999 - val_loss: 0.1984 - val_accuracy: 0.9812
# Epoch 95/100
# 375/375 [==============================] - 3s 7ms/step - loss: 7.4898e-04 - accuracy: 0.9998 - val_loss: 0.1957 - val_accuracy: 0.9806
# Epoch 96/100
# 375/375 [==============================] - 3s 7ms/step - loss: 5.2064e-04 - accuracy: 0.9998 - val_loss: 0.1831 - val_accuracy: 0.9818
# Epoch 97/100
# 375/375 [==============================] - 3s 8ms/step - loss: 5.8529e-04 - accuracy: 0.9998 - val_loss: 0.1854 - val_accuracy: 0.9820
# Epoch 98/100
# 375/375 [==============================] - 3s 7ms/step - loss: 4.1688e-04 - accuracy: 0.9998 - val_loss: 0.1898 - val_accuracy: 0.9819
# Epoch 99/100
# 375/375 [==============================] - 3s 7ms/step - loss: 4.4152e-04 - accuracy: 0.9999 - val_loss: 0.2023 - val_accuracy: 0.9814
# Epoch 100/100
# 375/375 [==============================] - 3s 7ms/step - loss: 6.5366e-04 - accuracy: 0.9998 - val_loss: 0.1840 - val_accuracy: 0.9830
# CPU times: user 4min 40s, sys: 28.7 s, total: 5min 9s
# Wall time: 5min 24s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1493 - accuracy: 0.9858
# Loss = 0.14930
# Accuracy = 0.98580

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
