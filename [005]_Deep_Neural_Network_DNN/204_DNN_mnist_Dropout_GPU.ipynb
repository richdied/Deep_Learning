# %% [markdown]
# # MNIST - Categorical Classification
# > # Dropout

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 2개의 Hidden Layers & 768개의 Nodes
#  - Model Capacity는 기존과 동일
#  - Dropout Layers 적용

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dropout(0.4))
mnist.add(layers.Dense(256, activation = 'relu'))
mnist.add(layers.Dropout(0.2))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 6s 7ms/step - loss: 0.3208 - accuracy: 0.9029 - val_loss: 0.1402 - val_accuracy: 0.9572
# Epoch 2/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1447 - accuracy: 0.9561 - val_loss: 0.1041 - val_accuracy: 0.9705
# Epoch 3/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1080 - accuracy: 0.9661 - val_loss: 0.0990 - val_accuracy: 0.9703
# Epoch 4/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0918 - accuracy: 0.9720 - val_loss: 0.0875 - val_accuracy: 0.9752
# Epoch 5/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0768 - accuracy: 0.9766 - val_loss: 0.0960 - val_accuracy: 0.9747
# Epoch 6/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0705 - accuracy: 0.9789 - val_loss: 0.0831 - val_accuracy: 0.9793
# Epoch 7/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0636 - accuracy: 0.9808 - val_loss: 0.0847 - val_accuracy: 0.9790
# Epoch 8/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0576 - accuracy: 0.9830 - val_loss: 0.0841 - val_accuracy: 0.9795
# Epoch 9/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0524 - accuracy: 0.9840 - val_loss: 0.0875 - val_accuracy: 0.9793
# Epoch 10/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0520 - accuracy: 0.9855 - val_loss: 0.0884 - val_accuracy: 0.9795
# Epoch 11/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0470 - accuracy: 0.9856 - val_loss: 0.0916 - val_accuracy: 0.9801
# Epoch 12/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0429 - accuracy: 0.9871 - val_loss: 0.0920 - val_accuracy: 0.9798
# Epoch 13/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0405 - accuracy: 0.9873 - val_loss: 0.0970 - val_accuracy: 0.9810
# Epoch 14/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0420 - accuracy: 0.9881 - val_loss: 0.0955 - val_accuracy: 0.9817
# Epoch 15/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0397 - accuracy: 0.9883 - val_loss: 0.1073 - val_accuracy: 0.9815
# Epoch 16/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0360 - accuracy: 0.9896 - val_loss: 0.1126 - val_accuracy: 0.9802
# Epoch 17/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0352 - accuracy: 0.9898 - val_loss: 0.1123 - val_accuracy: 0.9817
# Epoch 18/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0335 - accuracy: 0.9906 - val_loss: 0.1114 - val_accuracy: 0.9819
# Epoch 19/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0347 - accuracy: 0.9896 - val_loss: 0.1085 - val_accuracy: 0.9798
# Epoch 20/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0335 - accuracy: 0.9905 - val_loss: 0.1141 - val_accuracy: 0.9813
# Epoch 21/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0301 - accuracy: 0.9909 - val_loss: 0.1161 - val_accuracy: 0.9810
# Epoch 22/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0311 - accuracy: 0.9915 - val_loss: 0.1161 - val_accuracy: 0.9802
# Epoch 23/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0311 - accuracy: 0.9914 - val_loss: 0.1328 - val_accuracy: 0.9797
# Epoch 24/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0297 - accuracy: 0.9913 - val_loss: 0.1229 - val_accuracy: 0.9815
# Epoch 25/100
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0308 - accuracy: 0.9914 - val_loss: 0.1260 - val_accuracy: 0.9821
# Epoch 26/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.1236 - val_accuracy: 0.9823
# Epoch 27/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0275 - accuracy: 0.9925 - val_loss: 0.1376 - val_accuracy: 0.9803
# Epoch 28/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0259 - accuracy: 0.9929 - val_loss: 0.1281 - val_accuracy: 0.9819
# Epoch 29/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.1224 - val_accuracy: 0.9830
# Epoch 30/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0242 - accuracy: 0.9933 - val_loss: 0.1330 - val_accuracy: 0.9818
# Epoch 31/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0262 - accuracy: 0.9928 - val_loss: 0.1462 - val_accuracy: 0.9815
# Epoch 32/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0272 - accuracy: 0.9932 - val_loss: 0.1345 - val_accuracy: 0.9815
# Epoch 33/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0239 - accuracy: 0.9931 - val_loss: 0.1372 - val_accuracy: 0.9831
# Epoch 34/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0254 - accuracy: 0.9935 - val_loss: 0.1368 - val_accuracy: 0.9827
# Epoch 35/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0247 - accuracy: 0.9934 - val_loss: 0.1349 - val_accuracy: 0.9832
# Epoch 36/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0231 - accuracy: 0.9934 - val_loss: 0.1368 - val_accuracy: 0.9827
# Epoch 37/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.1562 - val_accuracy: 0.9831
# Epoch 38/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0248 - accuracy: 0.9938 - val_loss: 0.1543 - val_accuracy: 0.9829
# Epoch 39/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0220 - accuracy: 0.9945 - val_loss: 0.1535 - val_accuracy: 0.9832
# Epoch 40/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.1694 - val_accuracy: 0.9807
# Epoch 41/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0215 - accuracy: 0.9946 - val_loss: 0.1595 - val_accuracy: 0.9830
# Epoch 42/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0220 - accuracy: 0.9942 - val_loss: 0.1563 - val_accuracy: 0.9825
# Epoch 43/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0204 - accuracy: 0.9949 - val_loss: 0.1642 - val_accuracy: 0.9836
# Epoch 44/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0218 - accuracy: 0.9947 - val_loss: 0.1664 - val_accuracy: 0.9826
# Epoch 45/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.9951 - val_loss: 0.1815 - val_accuracy: 0.9816
# Epoch 46/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0216 - accuracy: 0.9945 - val_loss: 0.1583 - val_accuracy: 0.9830
# Epoch 47/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0184 - accuracy: 0.9949 - val_loss: 0.1901 - val_accuracy: 0.9807
# Epoch 48/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.1737 - val_accuracy: 0.9818
# Epoch 49/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0191 - accuracy: 0.9951 - val_loss: 0.1793 - val_accuracy: 0.9823
# Epoch 50/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0201 - accuracy: 0.9953 - val_loss: 0.1703 - val_accuracy: 0.9816
# Epoch 51/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0211 - accuracy: 0.9949 - val_loss: 0.1805 - val_accuracy: 0.9828
# Epoch 52/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9955 - val_loss: 0.1868 - val_accuracy: 0.9826
# Epoch 53/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.1666 - val_accuracy: 0.9835
# Epoch 54/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.9952 - val_loss: 0.1698 - val_accuracy: 0.9837
# Epoch 55/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0184 - accuracy: 0.9953 - val_loss: 0.1698 - val_accuracy: 0.9832
# Epoch 56/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0197 - accuracy: 0.9956 - val_loss: 0.1852 - val_accuracy: 0.9833
# Epoch 57/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0208 - accuracy: 0.9954 - val_loss: 0.1769 - val_accuracy: 0.9823
# Epoch 58/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0206 - accuracy: 0.9951 - val_loss: 0.1831 - val_accuracy: 0.9833
# Epoch 59/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0191 - accuracy: 0.9952 - val_loss: 0.1754 - val_accuracy: 0.9835
# Epoch 60/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0218 - accuracy: 0.9957 - val_loss: 0.1728 - val_accuracy: 0.9833
# Epoch 61/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0188 - accuracy: 0.9954 - val_loss: 0.1933 - val_accuracy: 0.9833
# Epoch 62/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0212 - accuracy: 0.9955 - val_loss: 0.1862 - val_accuracy: 0.9834
# Epoch 63/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0159 - accuracy: 0.9960 - val_loss: 0.1834 - val_accuracy: 0.9833
# Epoch 64/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.1797 - val_accuracy: 0.9838
# Epoch 65/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0205 - accuracy: 0.9956 - val_loss: 0.1884 - val_accuracy: 0.9838
# Epoch 66/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0187 - accuracy: 0.9953 - val_loss: 0.1979 - val_accuracy: 0.9823
# Epoch 67/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9957 - val_loss: 0.1881 - val_accuracy: 0.9834
# Epoch 68/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9961 - val_loss: 0.1947 - val_accuracy: 0.9825
# Epoch 69/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0180 - accuracy: 0.9958 - val_loss: 0.1855 - val_accuracy: 0.9825
# Epoch 70/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0196 - accuracy: 0.9958 - val_loss: 0.1957 - val_accuracy: 0.9830
# Epoch 71/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0182 - accuracy: 0.9959 - val_loss: 0.1981 - val_accuracy: 0.9821
# Epoch 72/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0192 - accuracy: 0.9959 - val_loss: 0.1882 - val_accuracy: 0.9822
# Epoch 73/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0162 - accuracy: 0.9967 - val_loss: 0.2156 - val_accuracy: 0.9821
# Epoch 74/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0177 - accuracy: 0.9965 - val_loss: 0.2062 - val_accuracy: 0.9814
# Epoch 75/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0184 - accuracy: 0.9961 - val_loss: 0.2074 - val_accuracy: 0.9827
# Epoch 76/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0193 - accuracy: 0.9959 - val_loss: 0.2073 - val_accuracy: 0.9838
# Epoch 77/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0201 - accuracy: 0.9956 - val_loss: 0.2162 - val_accuracy: 0.9827
# Epoch 78/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0156 - accuracy: 0.9964 - val_loss: 0.2116 - val_accuracy: 0.9830
# Epoch 79/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0179 - accuracy: 0.9965 - val_loss: 0.2089 - val_accuracy: 0.9839
# Epoch 80/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0159 - accuracy: 0.9963 - val_loss: 0.2091 - val_accuracy: 0.9845
# Epoch 81/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0185 - accuracy: 0.9960 - val_loss: 0.1969 - val_accuracy: 0.9835
# Epoch 82/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0165 - accuracy: 0.9964 - val_loss: 0.2160 - val_accuracy: 0.9824
# Epoch 83/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0195 - accuracy: 0.9963 - val_loss: 0.2050 - val_accuracy: 0.9832
# Epoch 84/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0196 - accuracy: 0.9960 - val_loss: 0.2164 - val_accuracy: 0.9827
# Epoch 85/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0205 - accuracy: 0.9960 - val_loss: 0.2113 - val_accuracy: 0.9830
# Epoch 86/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0166 - accuracy: 0.9966 - val_loss: 0.2076 - val_accuracy: 0.9832
# Epoch 87/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0142 - accuracy: 0.9966 - val_loss: 0.2213 - val_accuracy: 0.9827
# Epoch 88/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0161 - accuracy: 0.9965 - val_loss: 0.2286 - val_accuracy: 0.9818
# Epoch 89/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 0.2179 - val_accuracy: 0.9841
# Epoch 90/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0167 - accuracy: 0.9967 - val_loss: 0.2159 - val_accuracy: 0.9833
# Epoch 91/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0168 - accuracy: 0.9967 - val_loss: 0.2234 - val_accuracy: 0.9833
# Epoch 92/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9967 - val_loss: 0.2241 - val_accuracy: 0.9840
# Epoch 93/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0146 - accuracy: 0.9966 - val_loss: 0.2369 - val_accuracy: 0.9838
# Epoch 94/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0162 - accuracy: 0.9966 - val_loss: 0.2259 - val_accuracy: 0.9846
# Epoch 95/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0149 - accuracy: 0.9970 - val_loss: 0.2435 - val_accuracy: 0.9824
# Epoch 96/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9970 - val_loss: 0.2222 - val_accuracy: 0.9827
# Epoch 97/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0176 - accuracy: 0.9963 - val_loss: 0.2211 - val_accuracy: 0.9841
# Epoch 98/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0178 - accuracy: 0.9966 - val_loss: 0.2266 - val_accuracy: 0.9846
# Epoch 99/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9966 - val_loss: 0.2307 - val_accuracy: 0.9846
# Epoch 100/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0165 - accuracy: 0.9965 - val_loss: 0.2415 - val_accuracy: 0.9833
# CPU times: user 3min 44s, sys: 30.5 s, total: 4min 14s
# Wall time: 4min 23s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2028 - accuracy: 0.9834
# Loss = 0.20283
# Accuracy = 0.98340

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
