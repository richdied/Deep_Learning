# %% [markdown]
# # MNIST - Categorical Classification
# > # L2 Regularization

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 2개의 Hidden Layers & 768개의 Nodes
#  - Model Capacity는 기존과 동일
#  - L2 Regularization 적용

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

mnist = models.Sequential()
mnist.add(layers.Dense(512, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001),
                       input_shape=(28 * 28,)))
mnist.add(layers.Dense(256, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 4분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 7s 7ms/step - loss: 0.2651 - accuracy: 0.9220 - val_loss: 0.1266 - val_accuracy: 0.9651
# Epoch 2/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1050 - accuracy: 0.9712 - val_loss: 0.1035 - val_accuracy: 0.9724
# Epoch 3/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0711 - accuracy: 0.9809 - val_loss: 0.1020 - val_accuracy: 0.9737
# Epoch 4/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0549 - accuracy: 0.9855 - val_loss: 0.1012 - val_accuracy: 0.9754
# Epoch 5/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0445 - accuracy: 0.9890 - val_loss: 0.1003 - val_accuracy: 0.9769
# Epoch 6/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0370 - accuracy: 0.9919 - val_loss: 0.1046 - val_accuracy: 0.9776
# Epoch 7/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0345 - accuracy: 0.9926 - val_loss: 0.1045 - val_accuracy: 0.9796
# Epoch 8/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0305 - accuracy: 0.9938 - val_loss: 0.1216 - val_accuracy: 0.9761
# Epoch 9/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0281 - accuracy: 0.9944 - val_loss: 0.1066 - val_accuracy: 0.9793
# Epoch 10/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0261 - accuracy: 0.9951 - val_loss: 0.1221 - val_accuracy: 0.9783
# Epoch 11/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0257 - accuracy: 0.9951 - val_loss: 0.1240 - val_accuracy: 0.9777
# Epoch 12/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0239 - accuracy: 0.9956 - val_loss: 0.1565 - val_accuracy: 0.9708
# Epoch 13/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0224 - accuracy: 0.9959 - val_loss: 0.1103 - val_accuracy: 0.9790
# Epoch 14/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0225 - accuracy: 0.9960 - val_loss: 0.1386 - val_accuracy: 0.9754
# Epoch 15/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0207 - accuracy: 0.9961 - val_loss: 0.1292 - val_accuracy: 0.9761
# Epoch 16/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0204 - accuracy: 0.9966 - val_loss: 0.1211 - val_accuracy: 0.9789
# Epoch 17/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9967 - val_loss: 0.1155 - val_accuracy: 0.9801
# Epoch 18/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0188 - accuracy: 0.9969 - val_loss: 0.1300 - val_accuracy: 0.9765
# Epoch 19/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0187 - accuracy: 0.9969 - val_loss: 0.1370 - val_accuracy: 0.9762
# Epoch 20/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0192 - accuracy: 0.9967 - val_loss: 0.1226 - val_accuracy: 0.9780
# Epoch 21/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0182 - accuracy: 0.9967 - val_loss: 0.1199 - val_accuracy: 0.9780
# Epoch 22/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0176 - accuracy: 0.9970 - val_loss: 0.1601 - val_accuracy: 0.9733
# Epoch 23/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0173 - accuracy: 0.9971 - val_loss: 0.1509 - val_accuracy: 0.9725
# Epoch 24/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 0.1187 - val_accuracy: 0.9796
# Epoch 25/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0179 - accuracy: 0.9973 - val_loss: 0.1334 - val_accuracy: 0.9778
# Epoch 26/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0163 - accuracy: 0.9973 - val_loss: 0.1333 - val_accuracy: 0.9780
# Epoch 27/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0155 - accuracy: 0.9975 - val_loss: 0.1271 - val_accuracy: 0.9788
# Epoch 28/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0163 - accuracy: 0.9971 - val_loss: 0.1203 - val_accuracy: 0.9805
# Epoch 29/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0157 - accuracy: 0.9974 - val_loss: 0.1265 - val_accuracy: 0.9789
# Epoch 30/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0153 - accuracy: 0.9975 - val_loss: 0.1323 - val_accuracy: 0.9761
# Epoch 31/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0157 - accuracy: 0.9971 - val_loss: 0.1231 - val_accuracy: 0.9788
# Epoch 32/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.9974 - val_loss: 0.1502 - val_accuracy: 0.9757
# Epoch 33/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0139 - accuracy: 0.9979 - val_loss: 0.1852 - val_accuracy: 0.9697
# Epoch 34/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0144 - accuracy: 0.9976 - val_loss: 0.1234 - val_accuracy: 0.9798
# Epoch 35/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0134 - accuracy: 0.9979 - val_loss: 0.1302 - val_accuracy: 0.9775
# Epoch 36/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0143 - accuracy: 0.9976 - val_loss: 0.1230 - val_accuracy: 0.9796
# Epoch 37/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0140 - accuracy: 0.9974 - val_loss: 0.1428 - val_accuracy: 0.9787
# Epoch 38/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.1647 - val_accuracy: 0.9735
# Epoch 39/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0144 - accuracy: 0.9974 - val_loss: 0.1386 - val_accuracy: 0.9773
# Epoch 40/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 0.1371 - val_accuracy: 0.9789
# Epoch 41/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 0.1296 - val_accuracy: 0.9799
# Epoch 42/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0137 - accuracy: 0.9975 - val_loss: 0.1360 - val_accuracy: 0.9767
# Epoch 43/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0150 - accuracy: 0.9973 - val_loss: 0.1266 - val_accuracy: 0.9778
# Epoch 44/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9976 - val_loss: 0.1261 - val_accuracy: 0.9792
# Epoch 45/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9981 - val_loss: 0.1653 - val_accuracy: 0.9745
# Epoch 46/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 0.1394 - val_accuracy: 0.9778
# Epoch 47/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9983 - val_loss: 0.1315 - val_accuracy: 0.9778
# Epoch 48/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 0.1288 - val_accuracy: 0.9773
# Epoch 49/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9980 - val_loss: 0.1250 - val_accuracy: 0.9790
# Epoch 50/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0127 - accuracy: 0.9977 - val_loss: 0.1425 - val_accuracy: 0.9769
# Epoch 51/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9981 - val_loss: 0.1156 - val_accuracy: 0.9819
# Epoch 52/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.1428 - val_accuracy: 0.9793
# Epoch 53/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 0.1273 - val_accuracy: 0.9775
# Epoch 54/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9976 - val_loss: 0.1394 - val_accuracy: 0.9787
# Epoch 55/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0127 - accuracy: 0.9975 - val_loss: 0.1596 - val_accuracy: 0.9728
# Epoch 56/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0116 - accuracy: 0.9979 - val_loss: 0.1519 - val_accuracy: 0.9769
# Epoch 57/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9982 - val_loss: 0.1868 - val_accuracy: 0.9682
# Epoch 58/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0120 - accuracy: 0.9981 - val_loss: 0.1380 - val_accuracy: 0.9788
# Epoch 59/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 0.1371 - val_accuracy: 0.9793
# Epoch 60/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0121 - accuracy: 0.9978 - val_loss: 0.1273 - val_accuracy: 0.9805
# Epoch 61/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9982 - val_loss: 0.1365 - val_accuracy: 0.9787
# Epoch 62/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 0.1356 - val_accuracy: 0.9779
# Epoch 63/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 0.1451 - val_accuracy: 0.9755
# Epoch 64/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0121 - accuracy: 0.9979 - val_loss: 0.1541 - val_accuracy: 0.9759
# Epoch 65/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0115 - accuracy: 0.9978 - val_loss: 0.1506 - val_accuracy: 0.9784
# Epoch 66/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9980 - val_loss: 0.1342 - val_accuracy: 0.9782
# Epoch 67/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 0.1701 - val_accuracy: 0.9743
# Epoch 68/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0108 - accuracy: 0.9984 - val_loss: 0.1373 - val_accuracy: 0.9803
# Epoch 69/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9980 - val_loss: 0.1307 - val_accuracy: 0.9803
# Epoch 70/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9985 - val_loss: 0.1420 - val_accuracy: 0.9785
# Epoch 71/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9982 - val_loss: 0.1544 - val_accuracy: 0.9767
# Epoch 72/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0115 - accuracy: 0.9981 - val_loss: 0.1552 - val_accuracy: 0.9775
# Epoch 73/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9979 - val_loss: 0.1588 - val_accuracy: 0.9765
# Epoch 74/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9981 - val_loss: 0.1407 - val_accuracy: 0.9787
# Epoch 75/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9983 - val_loss: 0.1475 - val_accuracy: 0.9766
# Epoch 76/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9981 - val_loss: 0.1338 - val_accuracy: 0.9805
# Epoch 77/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0121 - accuracy: 0.9979 - val_loss: 0.1488 - val_accuracy: 0.9778
# Epoch 78/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9984 - val_loss: 0.1248 - val_accuracy: 0.9805
# Epoch 79/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9982 - val_loss: 0.1382 - val_accuracy: 0.9783
# Epoch 80/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0108 - accuracy: 0.9982 - val_loss: 0.1437 - val_accuracy: 0.9778
# Epoch 81/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0120 - accuracy: 0.9982 - val_loss: 0.1742 - val_accuracy: 0.9745
# Epoch 82/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 0.1390 - val_accuracy: 0.9786
# Epoch 83/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9984 - val_loss: 0.1426 - val_accuracy: 0.9777
# Epoch 84/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.1264 - val_accuracy: 0.9798
# Epoch 85/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9982 - val_loss: 0.1381 - val_accuracy: 0.9789
# Epoch 86/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9984 - val_loss: 0.1432 - val_accuracy: 0.9780
# Epoch 87/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9980 - val_loss: 0.1296 - val_accuracy: 0.9782
# Epoch 88/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0108 - accuracy: 0.9983 - val_loss: 0.1681 - val_accuracy: 0.9766
# Epoch 89/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0106 - accuracy: 0.9981 - val_loss: 0.1394 - val_accuracy: 0.9791
# Epoch 90/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9981 - val_loss: 0.1370 - val_accuracy: 0.9793
# Epoch 91/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0115 - accuracy: 0.9981 - val_loss: 0.1496 - val_accuracy: 0.9778
# Epoch 92/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9983 - val_loss: 0.1625 - val_accuracy: 0.9765
# Epoch 93/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9980 - val_loss: 0.1392 - val_accuracy: 0.9790
# Epoch 94/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9981 - val_loss: 0.1443 - val_accuracy: 0.9780
# Epoch 95/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9984 - val_loss: 0.1515 - val_accuracy: 0.9784
# Epoch 96/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0106 - accuracy: 0.9982 - val_loss: 0.1462 - val_accuracy: 0.9783
# Epoch 97/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9980 - val_loss: 0.1488 - val_accuracy: 0.9783
# Epoch 98/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9982 - val_loss: 0.1337 - val_accuracy: 0.9799
# Epoch 99/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9986 - val_loss: 0.1398 - val_accuracy: 0.9794
# Epoch 100/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9979 - val_loss: 0.1797 - val_accuracy: 0.9734
# CPU times: user 3min 37s, sys: 33.1 s, total: 4min 10s
# Wall time: 3min 40s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1891 - accuracy: 0.9734
# Loss = 0.18912
# Accuracy = 0.97340

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
