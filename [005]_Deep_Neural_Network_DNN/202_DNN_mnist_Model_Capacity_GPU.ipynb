# %% [markdown]
# # MNIST - Categorical Classification
# > # Model Capacity

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 1개의 Hidden Layer & 256개의 Nodes
#  - Model Capacity 낮게 조정

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(256, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 4분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 5s 5ms/step - loss: 0.3198 - accuracy: 0.9097 - val_loss: 0.1706 - val_accuracy: 0.9542
# Epoch 2/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1425 - accuracy: 0.9584 - val_loss: 0.1237 - val_accuracy: 0.9650
# Epoch 3/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0985 - accuracy: 0.9710 - val_loss: 0.1029 - val_accuracy: 0.9718
# Epoch 4/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0737 - accuracy: 0.9790 - val_loss: 0.0937 - val_accuracy: 0.9733
# Epoch 5/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0580 - accuracy: 0.9830 - val_loss: 0.0912 - val_accuracy: 0.9734
# Epoch 6/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0459 - accuracy: 0.9872 - val_loss: 0.0874 - val_accuracy: 0.9738
# Epoch 7/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0360 - accuracy: 0.9900 - val_loss: 0.0855 - val_accuracy: 0.9754
# Epoch 8/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0300 - accuracy: 0.9913 - val_loss: 0.0825 - val_accuracy: 0.9769
# Epoch 9/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0242 - accuracy: 0.9936 - val_loss: 0.0880 - val_accuracy: 0.9763
# Epoch 10/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0200 - accuracy: 0.9942 - val_loss: 0.0868 - val_accuracy: 0.9761
# Epoch 11/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.0856 - val_accuracy: 0.9781
# Epoch 12/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0129 - accuracy: 0.9966 - val_loss: 0.0893 - val_accuracy: 0.9783
# Epoch 13/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.0976 - val_accuracy: 0.9763
# Epoch 14/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0087 - accuracy: 0.9979 - val_loss: 0.0917 - val_accuracy: 0.9793
# Epoch 15/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.1149 - val_accuracy: 0.9738
# Epoch 16/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0955 - val_accuracy: 0.9792
# Epoch 17/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0975 - val_accuracy: 0.9787
# Epoch 18/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.1005 - val_accuracy: 0.9784
# Epoch 19/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.1072 - val_accuracy: 0.9793
# Epoch 20/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1174 - val_accuracy: 0.9773
# Epoch 21/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1158 - val_accuracy: 0.9781
# Epoch 22/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1099 - val_accuracy: 0.9795
# Epoch 23/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1191 - val_accuracy: 0.9790
# Epoch 24/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1201 - val_accuracy: 0.9797
# Epoch 25/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.4150e-04 - accuracy: 0.9998 - val_loss: 0.1271 - val_accuracy: 0.9786
# Epoch 26/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.7647e-04 - accuracy: 0.9999 - val_loss: 0.1250 - val_accuracy: 0.9801
# Epoch 27/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.1091e-04 - accuracy: 0.9999 - val_loss: 0.1342 - val_accuracy: 0.9777
# Epoch 28/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.2458e-04 - accuracy: 0.9999 - val_loss: 0.1335 - val_accuracy: 0.9782
# Epoch 29/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.0922e-04 - accuracy: 0.9999 - val_loss: 0.1372 - val_accuracy: 0.9799
# Epoch 30/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.3732e-04 - accuracy: 0.9999 - val_loss: 0.1366 - val_accuracy: 0.9794
# Epoch 31/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.9763e-04 - accuracy: 0.9999 - val_loss: 0.1370 - val_accuracy: 0.9807
# Epoch 32/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6108e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9808
# Epoch 33/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.3860e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9804
# Epoch 34/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.5426e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9797
# Epoch 35/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.4302e-05 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9807
# Epoch 36/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0002e-04 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9806
# Epoch 37/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.2136e-05 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9812
# Epoch 38/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.5228e-05 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9810
# Epoch 39/100
# 375/375 [==============================] - 2s 6ms/step - loss: 1.0269e-04 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9815
# Epoch 40/100
# 375/375 [==============================] - 2s 5ms/step - loss: 3.2175e-05 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9804
# Epoch 41/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.9008e-05 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9799
# Epoch 42/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6728e-05 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9796
# Epoch 43/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6377e-05 - accuracy: 1.0000 - val_loss: 0.1787 - val_accuracy: 0.9793
# Epoch 44/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.3196e-06 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9805
# Epoch 45/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.5563e-06 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9799
# Epoch 46/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.3414e-06 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9809
# Epoch 47/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.1094e-06 - accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 0.9807
# Epoch 48/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.3253e-06 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 0.9816
# Epoch 49/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.9338e-06 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 0.9811
# Epoch 50/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.5324e-06 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9818
# Epoch 51/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.8980e-07 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9809
# Epoch 52/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.2448e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9821
# Epoch 53/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6080e-07 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.9820
# Epoch 54/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.6944e-07 - accuracy: 1.0000 - val_loss: 0.1873 - val_accuracy: 0.9818
# Epoch 55/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.3254e-08 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9821
# Epoch 56/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.2965e-08 - accuracy: 1.0000 - val_loss: 0.1910 - val_accuracy: 0.9816
# Epoch 57/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.8192e-08 - accuracy: 1.0000 - val_loss: 0.1915 - val_accuracy: 0.9820
# Epoch 58/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.3135e-08 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9818
# Epoch 59/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.9909e-08 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 0.9822
# Epoch 60/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.7113e-08 - accuracy: 1.0000 - val_loss: 0.1925 - val_accuracy: 0.9818
# Epoch 61/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.5518e-08 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9819
# Epoch 62/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.3834e-08 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9815
# Epoch 63/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.2126e-08 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9820
# Epoch 64/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.1038e-08 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9817
# Epoch 65/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.9973e-08 - accuracy: 1.0000 - val_loss: 0.1952 - val_accuracy: 0.9820
# Epoch 66/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.8803e-08 - accuracy: 1.0000 - val_loss: 0.1957 - val_accuracy: 0.9818
# Epoch 67/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.7963e-08 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9815
# Epoch 68/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.7151e-08 - accuracy: 1.0000 - val_loss: 0.1959 - val_accuracy: 0.9820
# Epoch 69/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6337e-08 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9821
# Epoch 70/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.5671e-08 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9818
# Epoch 71/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.5189e-08 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9821
# Epoch 72/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.4563e-08 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9814
# Epoch 73/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.3918e-08 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9818
# Epoch 74/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.3590e-08 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9819
# Epoch 75/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.3178e-08 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9817
# Epoch 76/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2820e-08 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9817
# Epoch 77/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9813
# Epoch 78/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1938e-08 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9819
# Epoch 79/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1737e-08 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9818
# Epoch 80/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1330e-08 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9818
# Epoch 81/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0925e-08 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9817
# Epoch 82/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0759e-08 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9816
# Epoch 83/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0421e-08 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9816
# Epoch 84/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0309e-08 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9818
# Epoch 85/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.9118e-09 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9817
# Epoch 86/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.8298e-09 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9817
# Epoch 87/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.5963e-09 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9816
# Epoch 88/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.3679e-09 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9817
# Epoch 89/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.1915e-09 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9816
# Epoch 90/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.9978e-09 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9813
# Epoch 91/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.9159e-09 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9814
# Epoch 92/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.6327e-09 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9815
# Epoch 93/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.4986e-09 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9818
# Epoch 94/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.3968e-09 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9815
# Epoch 95/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.1907e-09 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9815
# Epoch 96/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.1186e-09 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9816
# Epoch 97/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.0317e-09 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9817
# Epoch 98/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.8777e-09 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9814
# Epoch 99/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.6716e-09 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9816
# Epoch 100/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.6517e-09 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9818
# CPU times: user 2min 47s, sys: 27.6 s, total: 3min 15s
# Wall time: 3min 23s

# %% [markdown]
# > ## 4) 학습 결과 시각화 - Overfitting

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1628 - accuracy: 0.9827
# Loss = 0.16283
# Accuracy = 0.98270

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
