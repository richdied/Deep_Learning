# %% [markdown]
# # Variational AutoEncoder(VAE)
#
# * Representation Learning(표현 학습)
#  - 개념 벡터(Concept Vector) : 잠재공간(Latent Space)이나 임베딩(Embedding)이 주어지면 이 공간의 어떤 방향은 원본데이터의 변화를 인코딩한 축일 수 있음.
#  - 개념 벡터의 연산으로 변형된 이미지를 복원(Decoding)하여 생성 가능
# * Example
#  - 원통의 '높이'와 '너비'
#    - 높이가 낮고 너비가 넓은 원통 이미지 생성
#  - 눈의 '크기' 및 '색', 머리카락의 '길이' 및 '색'
#    - 긴 검은 머리에 갈색의 큰 눈을 가진 이미지 생성
# * Decoder(Generator) 학습을 위해 Encoder 사용

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# > ## Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # I. Load MNIST Dataset

# %% [markdown]
# > ## 1) X_train, X_test and y_train, y_test

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# > ## 2) Normalization and Reshape

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

X_train = X_train.reshape(60000, 28 * 28)
X_test = X_test.reshape(10000, 28 * 28)

X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %% [markdown]
# # II. Keras Modeling with Functional API

# %% [markdown]
# > ## 1) 'Latent Space' Point Mapping
#
# * 각 이미지가 '잠재공간(Latent Space) 포인트' 주변의 '다변수 정규 분포(Mutilvariate Nodrmal Distribution)'에 매핑

# %%
from tensorflow.keras.layers import Input, Dense

input_img = Input(shape = (784,))

encoded = Dense(256, activation = 'elu')(input_img)
encoded = Dense(128, activation = 'elu')(encoded)

# %% [markdown]
# * Variational(Latent Space) Layers
#  - 평균(mean)과 분산(log_var)으로 인코딩된 잠재공간(Latent Space) 포인트 분포

# %%
mean = Dense(2, name = 'mean')(encoded)

log_var = Dense(2, name = 'var')(encoded)

# %% [markdown]
# > ## 2) 'Latent Space' Sampling
#
# * 잠재공간(Latent Space)의 잠재공간-포인트(z) 샘플링
#  - 정규분포상에서 무작위로 선택한 'epsilon'값 사용
#    - Encoding 결과값을 그대로 사용하면 항상 같은 결과만 생성
#    - 따라서 랜덤 샘플링을 통하여 기존 Data에 존재하지 않는 새로운 Image 생성
# * Lambda( ) : 임의의 파이썬 함수 객체를 Keras Layer로 생성
# * K.exp(log_var) : 로그분산 -> 표준편차 변환

# %%
from keras import backend as K
from keras.layers import Lambda

def sampling(args):
    mean, log_var = args
    epsilon = K.random_normal(shape = (100, 2), mean = 0., stddev = 1.0)
    return mean + K.exp(log_var) * epsilon

z = Lambda(sampling, output_shape = (2,))([mean, log_var])

# %% [markdown]
# > ## 3) 'encoder' Model

# %%
from tensorflow.keras.models import Model

encoder = Model(input_img, mean)

# %% [markdown]
# * encoder Model Summary

# %%
encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  mean (Dense)                (None, 2)                 258
#
# =================================================================
# Total params: 234,114
# Trainable params: 234,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 4) 'generator' Model
#
# * Decoding Layer Structure

# %%
decoder_1 = Dense(128, activation = 'elu')
decoder_2 = Dense(256, activation = 'elu')
decoder_3 = Dense(784, activation = 'sigmoid')

# %% [markdown]
# * 랜덤 샘플링 '잠재공간-포인트(Z)' 재구성

# %%
z_sample = decoder_1(z)
z_sample = decoder_2(z_sample)
z_sample = decoder_3(z_sample)

# %%
z_sample.shape
# Out:
# TensorShape([100, 784])

# %% [markdown]
# * Generator Layers

# %%
decoder_input = Input(shape = (2,))

y_gen = decoder_1(decoder_input)
y_gen = decoder_2(y_gen)
y_gen = decoder_3(y_gen)

# %% [markdown]
# * Build 'generator'

# %%
generator = Model(decoder_input, y_gen)

# %% [markdown]
# * 'generator' Model Summary

# %%
generator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_2 (Dense)             multiple                  384
#
#  dense_3 (Dense)             multiple                  33024
#
#  dense_4 (Dense)             multiple                  201488
#
# =================================================================
# Total params: 234,896
# Trainable params: 234,896
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # III. VAE Fit

# %% [markdown]
# > ## 1) 'vae' Model Define
#
# * Build 'vae' Model
#  * End-to-End AutoEncoder

# %%
vae = Model(input_img, z_sample)

# %% [markdown]
# * 'vae' Model Summary

# %%
vae.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 256)          200960      ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['dense[0][0]']
#
#  mean (Dense)                   (None, 2)            258         ['dense_1[0][0]']
#
#  var (Dense)                    (None, 2)            258         ['dense_1[0][0]']
#
#  lambda (Lambda)                (100, 2)             0           ['mean[0][0]',
#                                                                   'var[0][0]']
#
#  dense_2 (Dense)                multiple             384         ['lambda[0][0]']
#
#  dense_3 (Dense)                multiple             33024       ['dense_2[0][0]']
#
#  dense_4 (Dense)                multiple             201488      ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 469,268
# Trainable params: 469,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile
#
# * Define 'vae_loss'
#  - reconstruction_loss : 입력값 재구성 손실
#    - 원본 이미지와 생성된 이미지와의 오차(CEE)
#    - '샘플링 함수'로 생성한 'z' 값으로 얼마나 원본이미지와 유사한 이미지를 잘 생성하는가?
#  - kl_loss : 사전 분포와 잠재 분포 사이의 Kullback Leibler-Divergence(두 확률분포 간 거리)
#    - 사전 분포(Prior Distribution) : 원본 이미지 확률분포
#    - 잠재 분포(Latent Distribution) : 잠재공간 확률분포
#    - '샘플링 함수'의 값이 원본 이미지의 확률분포와 유사한가?

# %%
from tensorflow.keras import metrics

reconstruction_loss = metrics.binary_crossentropy(input_img, z_sample)
kl_loss = 0.0005 * K.mean(K.square(mean) + K.exp(log_var) - log_var - 1, axis = -1)

vae_loss = reconstruction_loss + kl_loss

# %% [markdown]
# * Add vae_loss

# %%
vae.add_loss(vae_loss)

# %% [markdown]
# * Compile with vae_loss

# %%
vae.compile(optimizer = 'adam')

# %% [markdown]
# > ## 3) Model Training
#
# * 약 6분

# %%
# %%time

vae.fit(X_train,
       shuffle = True,
       epochs = 100,
       batch_size = 100,
       validation_data = (X_test, None))
# Out:
# Epoch 1/100
# 600/600 [==============================] - 9s 6ms/step - loss: 0.2372 - val_loss: 0.2170
# Epoch 2/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2145 - val_loss: 0.2090
# Epoch 3/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2063 - val_loss: 0.2030
# Epoch 4/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2013 - val_loss: 0.1999
# Epoch 5/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1979 - val_loss: 0.1961
# Epoch 6/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1946 - val_loss: 0.1931
# Epoch 7/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1916 - val_loss: 0.1910
# Epoch 8/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1895 - val_loss: 0.1885
# Epoch 9/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1876 - val_loss: 0.1869
# Epoch 10/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1862 - val_loss: 0.1862
# Epoch 11/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1849 - val_loss: 0.1850
# Epoch 12/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1839 - val_loss: 0.1840
# Epoch 13/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1829 - val_loss: 0.1831
# Epoch 14/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1820 - val_loss: 0.1827
# Epoch 15/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1812 - val_loss: 0.1819
# Epoch 16/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1805 - val_loss: 0.1817
# Epoch 17/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1797 - val_loss: 0.1813
# Epoch 18/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1792 - val_loss: 0.1813
# Epoch 19/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1786 - val_loss: 0.1812
# Epoch 20/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1782 - val_loss: 0.1802
# Epoch 21/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1777 - val_loss: 0.1806
# Epoch 22/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1773 - val_loss: 0.1795
# Epoch 23/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1768 - val_loss: 0.1791
# Epoch 24/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1763 - val_loss: 0.1794
# Epoch 25/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1760 - val_loss: 0.1792
# Epoch 26/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1757 - val_loss: 0.1783
# Epoch 27/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1753 - val_loss: 0.1779
# Epoch 28/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1749 - val_loss: 0.1784
# Epoch 29/100
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1747 - val_loss: 0.1779
# Epoch 30/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1743 - val_loss: 0.1775
# Epoch 31/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1741 - val_loss: 0.1775
# Epoch 32/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1739 - val_loss: 0.1776
# Epoch 33/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1737 - val_loss: 0.1777
# Epoch 34/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1733 - val_loss: 0.1771
# Epoch 35/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1731 - val_loss: 0.1777
# Epoch 36/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1729 - val_loss: 0.1773
# Epoch 37/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1727 - val_loss: 0.1772
# Epoch 38/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1726 - val_loss: 0.1772
# Epoch 39/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1722 - val_loss: 0.1771
# Epoch 40/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1720 - val_loss: 0.1771
# Epoch 41/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1719 - val_loss: 0.1763
# Epoch 42/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1716 - val_loss: 0.1765
# Epoch 43/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1716 - val_loss: 0.1774
# Epoch 44/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1714 - val_loss: 0.1763
# Epoch 45/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1712 - val_loss: 0.1760
# Epoch 46/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1711 - val_loss: 0.1758
# Epoch 47/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1709 - val_loss: 0.1757
# Epoch 48/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1708 - val_loss: 0.1758
# Epoch 49/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1706 - val_loss: 0.1759
# Epoch 50/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1705 - val_loss: 0.1760
# Epoch 51/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1705 - val_loss: 0.1761
# Epoch 52/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1702 - val_loss: 0.1758
# Epoch 53/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1701 - val_loss: 0.1759
# Epoch 54/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1699 - val_loss: 0.1753
# Epoch 55/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1698 - val_loss: 0.1753
# Epoch 56/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1697 - val_loss: 0.1757
# Epoch 57/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1697 - val_loss: 0.1756
# Epoch 58/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1695 - val_loss: 0.1754
# Epoch 59/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1694 - val_loss: 0.1754
# Epoch 60/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1693 - val_loss: 0.1751
# Epoch 61/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1691 - val_loss: 0.1769
# Epoch 62/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1690 - val_loss: 0.1757
# Epoch 63/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1690 - val_loss: 0.1752
# Epoch 64/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1689 - val_loss: 0.1748
# Epoch 65/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1688 - val_loss: 0.1758
# Epoch 66/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1688 - val_loss: 0.1749
# Epoch 67/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1686 - val_loss: 0.1749
# Epoch 68/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1685 - val_loss: 0.1752
# Epoch 69/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1686 - val_loss: 0.1755
# Epoch 70/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1684 - val_loss: 0.1750
# Epoch 71/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1682 - val_loss: 0.1753
# Epoch 72/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1681 - val_loss: 0.1754
# Epoch 73/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1681 - val_loss: 0.1750
# Epoch 74/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1681 - val_loss: 0.1758
# Epoch 75/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1681 - val_loss: 0.1756
# Epoch 76/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1678 - val_loss: 0.1749
# Epoch 77/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1678 - val_loss: 0.1744
# Epoch 78/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1678 - val_loss: 0.1752
# Epoch 79/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1678 - val_loss: 0.1750
# Epoch 80/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1676 - val_loss: 0.1746
# Epoch 81/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1675 - val_loss: 0.1750
# Epoch 82/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1674 - val_loss: 0.1745
# Epoch 83/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1675 - val_loss: 0.1752
# Epoch 84/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1674 - val_loss: 0.1758
# Epoch 85/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1673 - val_loss: 0.1746
# Epoch 86/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1672 - val_loss: 0.1750
# Epoch 87/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1671 - val_loss: 0.1748
# Epoch 88/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1671 - val_loss: 0.1754
# Epoch 89/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1671 - val_loss: 0.1751
# Epoch 90/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1670 - val_loss: 0.1748
# Epoch 91/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1669 - val_loss: 0.1756
# Epoch 92/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1668 - val_loss: 0.1748
# Epoch 93/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1669 - val_loss: 0.1748
# Epoch 94/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1668 - val_loss: 0.1753
# Epoch 95/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1667 - val_loss: 0.1749
# Epoch 96/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1666 - val_loss: 0.1745
# Epoch 97/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1666 - val_loss: 0.1748
# Epoch 98/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1666 - val_loss: 0.1749
# Epoch 99/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1664 - val_loss: 0.1748
# Epoch 100/100
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1665 - val_loss: 0.1747
# CPU times: user 5min 2s, sys: 22.7 s, total: 5min 25s
# Wall time: 5min 24s

# %% [markdown]
# # IV. 'Latent Space' Visualization

# %% [markdown]
# > ## 1) Classes in the Latent Space

# %%
X_test_latent = encoder.predict(X_test, batch_size = 100)

plt.figure(figsize = (12, 10))
plt.scatter(X_test_latent[:, 0], X_test_latent[:, 1], c = y_test)
plt.colorbar()
plt.show()

# %% [markdown]
# > ## 2) Display 2D Manifold(20 * 20)
#
# * 두 개의 '개념 벡터(Concept Vector)'로 데이터의 특징을 '표현(Representation)'
#  - 두께, 회전각도 등

# %%
from scipy.stats import norm

n = 20
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = norm.ppf(np.linspace(0.05, 0.95, n)) 
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize = (10, 10))
plt.imshow(figure, cmap = 'Greys_r')
plt.show()

# %% [markdown]
# # V. 'generator' Test

# %% [markdown]
# > ## 1) 'encoder' Test (784 -> 2)

# %%
encoded_latent = encoder.predict(X_test)

encoded_latent.shape
# Out:
# (10000, 2)

# %% [markdown]
# > ## 2) 'generator' Test (2 -> 784)

# %%
generated_imgs = generator.predict(encoded_latent)

generated_imgs.shape
# Out:
# (10000, 784)

# %% [markdown]
# > ## 3) Generating Visualization
#
# * 복원이 아닌 생성된 이미지들

# %%
n = 10

plt.figure(figsize = (20, 4))
for i in range(n):

    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(generated_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
