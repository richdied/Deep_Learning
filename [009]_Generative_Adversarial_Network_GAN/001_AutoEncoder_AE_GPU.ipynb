# %% [markdown]
# # AutoEncoder(AE)
#
# * 입력데이터의 차원축소를 통해 의미있는 잠재 공간(Latent Space/Manifold)을 학습
#  - Encoder 학습을 위해 Decoder를 사용

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Load MNIST Dataset

# %% [markdown]
# > ## 1) X_train and X_test

# %%
from tensorflow.keras.datasets import mnist

(X_train, _), (X_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# > ## 2) Normalization and Reshape

# %%
X_train = X_train / 255.
X_test = X_test / 255.

X_train = X_train.reshape(60000, 28 * 28)
X_test = X_test.reshape(10000, 28 * 28)

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %% [markdown]
# # II. Keras Modeling with Functional API

# %% [markdown]
# > ## 1) 'Latent Space' Size

# %%
encoding_dim = 32

# %% [markdown]
# > ## 2) Encoder
#
# * Input

# %%
from tensorflow.keras import layers

input_img = layers.Input(shape = (784, ))

# %% [markdown]
# * Encoding Layers and Encoding Model

# %%
encoded = layers.Dense(256, activation = 'elu')(input_img)
encoded = layers.Dense(128, activation = 'elu')(encoded)
encoded = layers.Dense(encoding_dim, activation = 'elu')(encoded)

# %% [markdown]
# > ## 3) Decoder
#
# * Decoding Lyaers and Decoding Model

# %%
decoded = layers.Dense(128, activation = 'elu')(encoded)
decoded = layers.Dense(256, activation = 'elu')(decoded)
decoded = layers.Dense(784, activation = 'sigmoid')(decoded)

# %% [markdown]
# # III. AutoEncoder Model

# %% [markdown]
# > ## 1) 'autoencoder' Model

# %%
from tensorflow.keras import models

autoencoder = models.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dense_3 (Dense)             (None, 128)               4224
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dense_5 (Dense)             (None, 784)               201488
#
# =================================================================
# Total params: 476,720
# Trainable params: 476,720
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) 'encoder' Model

# %%
encoder = models.Model(input_img, encoded)

# %%
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 32)                4128
#
# =================================================================
# Total params: 237,984
# Trainable params: 237,984
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 3) 'decoder' Model

# %%
encoded_input = layers.Input(shape = (encoding_dim,))

decoder_layer = autoencoder.layers[-3](encoded_input)
decoder_layer = autoencoder.layers[-2](decoder_layer)
decoder_layer = autoencoder.layers[-1](decoder_layer)

decoder = models.Model(encoded_input, decoder_layer)

# %%
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense_3 (Dense)             (None, 128)               4224
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dense_5 (Dense)             (None, 784)               201488
#
# =================================================================
# Total params: 238,736
# Trainable params: 238,736
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # IV. Model Fit

# %% [markdown]
# > ## 1) Model Compile

# %%
autoencoder.compile(loss = 'binary_crossentropy',
                    optimizer = 'adam')

# %% [markdown]
# > ## 2) Model Training

# %%
autoencoder.fit(X_train, X_train,
                epochs = 50,
                batch_size = 256,
                validation_data = (X_test, X_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 5s 7ms/step - loss: 0.2015 - val_loss: 0.1388
# Epoch 2/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1250 - val_loss: 0.1139
# Epoch 3/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1103 - val_loss: 0.1054
# Epoch 4/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1044 - val_loss: 0.1012
# Epoch 5/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1010 - val_loss: 0.0986
# Epoch 6/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0984 - val_loss: 0.0959
# Epoch 7/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0963 - val_loss: 0.0946
# Epoch 8/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0948 - val_loss: 0.0936
# Epoch 9/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0935 - val_loss: 0.0921
# Epoch 10/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0924 - val_loss: 0.0915
# Epoch 11/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0916 - val_loss: 0.0905
# Epoch 12/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0907 - val_loss: 0.0898
# Epoch 13/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0899 - val_loss: 0.0891
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0890 - val_loss: 0.0881
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0883 - val_loss: 0.0873
# Epoch 16/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0876 - val_loss: 0.0870
# Epoch 17/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0870 - val_loss: 0.0864
# Epoch 18/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0863 - val_loss: 0.0857
# Epoch 19/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0857 - val_loss: 0.0848
# Epoch 20/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0852 - val_loss: 0.0848
# Epoch 21/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0847 - val_loss: 0.0844
# Epoch 22/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0843 - val_loss: 0.0837
# Epoch 23/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0839 - val_loss: 0.0834
# Epoch 24/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0834 - val_loss: 0.0830
# Epoch 25/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0831 - val_loss: 0.0830
# Epoch 26/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0828 - val_loss: 0.0825
# Epoch 27/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0824 - val_loss: 0.0821
# Epoch 28/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0821 - val_loss: 0.0819
# Epoch 29/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0818 - val_loss: 0.0816
# Epoch 30/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0815 - val_loss: 0.0813
# Epoch 31/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0812 - val_loss: 0.0813
# Epoch 32/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0810 - val_loss: 0.0809
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0808 - val_loss: 0.0810
# Epoch 34/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0806 - val_loss: 0.0806
# Epoch 35/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0805 - val_loss: 0.0805
# Epoch 36/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0803 - val_loss: 0.0805
# Epoch 37/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0802 - val_loss: 0.0801
# Epoch 38/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0800 - val_loss: 0.0801
# Epoch 39/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0799 - val_loss: 0.0800
# Epoch 40/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0797 - val_loss: 0.0800
# Epoch 41/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0796 - val_loss: 0.0797
# Epoch 42/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0795 - val_loss: 0.0799
# Epoch 43/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0794 - val_loss: 0.0799
# Epoch 44/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0793 - val_loss: 0.0794
# Epoch 45/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0792 - val_loss: 0.0793
# Epoch 46/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0790 - val_loss: 0.0794
# Epoch 47/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0789 - val_loss: 0.0790
# Epoch 48/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0788 - val_loss: 0.0789
# Epoch 49/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0787 - val_loss: 0.0791
# Epoch 50/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0785 - val_loss: 0.0789

# %% [markdown]
# # V. Model Predict

# %% [markdown]
# > ## 1) Imgae Encoding
#
# * Create 'Latent Space'

# %%
encoded_imgs = encoder.predict(X_test)

encoded_imgs.shape
# Out:
# (10000, 32)

# %% [markdown]
# > ## 2) 'Latent Space' Decoding

# %%
decoded_imgs = decoder.predict(encoded_imgs)

decoded_imgs.shape
# Out:
# (10000, 784)

# %% [markdown]
# # VI. Visualization
#
# * 10개의 이미지 데이터를 모델에 적용

# %%
import matplotlib.pyplot as plt

n = 10

plt.figure(figsize = (20, 4))
for i in range(n):

    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
