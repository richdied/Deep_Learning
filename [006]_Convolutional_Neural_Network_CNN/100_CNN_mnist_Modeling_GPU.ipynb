# %% [markdown]
# # MNIST - Categorical Classification
# > # Convolutional Neural Network

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.8.0'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28, 28, 1))
X_test = X_test.reshape((10000, 28, 28, 1))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction Layer

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
# =================================================================
# Total params: 55,744
# Trainable params: 55,744
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Classification Layer

# %%
model.add(layers.Flatten())
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 11분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 17s 16ms/step - loss: 0.2689 - accuracy: 0.9151 - val_loss: 0.0794 - val_accuracy: 0.9755
# Epoch 2/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0614 - accuracy: 0.9809 - val_loss: 0.0599 - val_accuracy: 0.9812
# Epoch 3/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0395 - accuracy: 0.9876 - val_loss: 0.0507 - val_accuracy: 0.9855
# Epoch 4/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0292 - accuracy: 0.9905 - val_loss: 0.0442 - val_accuracy: 0.9870
# Epoch 5/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.0395 - val_accuracy: 0.9893
# Epoch 6/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0180 - accuracy: 0.9938 - val_loss: 0.0419 - val_accuracy: 0.9889
# Epoch 7/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0446 - val_accuracy: 0.9887
# Epoch 8/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 0.0449 - val_accuracy: 0.9887
# Epoch 9/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0414 - val_accuracy: 0.9908
# Epoch 10/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0528 - val_accuracy: 0.9898
# Epoch 11/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0454 - val_accuracy: 0.9913
# Epoch 12/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0568 - val_accuracy: 0.9904
# Epoch 13/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0526 - val_accuracy: 0.9894
# Epoch 14/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0570 - val_accuracy: 0.9885
# Epoch 15/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0584 - val_accuracy: 0.9903
# Epoch 16/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0636 - val_accuracy: 0.9894
# Epoch 17/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0639 - val_accuracy: 0.9908
# Epoch 18/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0697 - val_accuracy: 0.9902
# Epoch 19/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0647 - val_accuracy: 0.9911
# Epoch 20/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0645 - val_accuracy: 0.9912
# Epoch 21/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0692 - val_accuracy: 0.9925
# Epoch 22/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0809 - val_accuracy: 0.9896
# Epoch 23/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0738 - val_accuracy: 0.9908
# Epoch 24/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0771 - val_accuracy: 0.9920
# Epoch 25/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0790 - val_accuracy: 0.9903
# Epoch 26/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0947 - val_accuracy: 0.9904
# Epoch 27/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0815 - val_accuracy: 0.9902
# Epoch 28/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0874 - val_accuracy: 0.9913
# Epoch 29/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0884 - val_accuracy: 0.9925
# Epoch 30/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0777 - val_accuracy: 0.9919
# Epoch 31/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1000 - val_accuracy: 0.9918
# Epoch 32/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1084 - val_accuracy: 0.9902
# Epoch 33/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.1013 - val_accuracy: 0.9912
# Epoch 34/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0921 - val_accuracy: 0.9915
# Epoch 35/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1109 - val_accuracy: 0.9908
# Epoch 36/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1444 - val_accuracy: 0.9893
# Epoch 37/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0984 - val_accuracy: 0.9912
# Epoch 38/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1057 - val_accuracy: 0.9909
# Epoch 39/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1092 - val_accuracy: 0.9905
# Epoch 40/100
# 375/375 [==============================] - 6s 15ms/step - loss: 7.1728e-04 - accuracy: 0.9997 - val_loss: 0.1314 - val_accuracy: 0.9898
# Epoch 41/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1141 - val_accuracy: 0.9913
# Epoch 42/100
# 375/375 [==============================] - 6s 16ms/step - loss: 9.8018e-04 - accuracy: 0.9998 - val_loss: 0.1261 - val_accuracy: 0.9915
# Epoch 43/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1298 - val_accuracy: 0.9908
# Epoch 44/100
# 375/375 [==============================] - 6s 16ms/step - loss: 9.9592e-04 - accuracy: 0.9998 - val_loss: 0.1213 - val_accuracy: 0.9915
# Epoch 45/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1187 - val_accuracy: 0.9910
# Epoch 46/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1780 - val_accuracy: 0.9878
# Epoch 47/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1031 - val_accuracy: 0.9914
# Epoch 48/100
# 375/375 [==============================] - 6s 16ms/step - loss: 7.4497e-04 - accuracy: 0.9998 - val_loss: 0.1240 - val_accuracy: 0.9913
# Epoch 49/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1258 - val_accuracy: 0.9912
# Epoch 50/100
# 375/375 [==============================] - 6s 16ms/step - loss: 8.0184e-04 - accuracy: 0.9998 - val_loss: 0.1129 - val_accuracy: 0.9921
# Epoch 51/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1263 - val_accuracy: 0.9916
# Epoch 52/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1518 - val_accuracy: 0.9904
# Epoch 53/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1106 - val_accuracy: 0.9913
# Epoch 54/100
# 375/375 [==============================] - 6s 16ms/step - loss: 9.5219e-04 - accuracy: 0.9999 - val_loss: 0.1194 - val_accuracy: 0.9908
# Epoch 55/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.1366 - val_accuracy: 0.9911
# Epoch 56/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1366 - val_accuracy: 0.9907
# Epoch 57/100
# 375/375 [==============================] - 6s 16ms/step - loss: 2.9099e-04 - accuracy: 0.9999 - val_loss: 0.1463 - val_accuracy: 0.9919
# Epoch 58/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1744 - val_accuracy: 0.9898
# Epoch 59/100
# 375/375 [==============================] - 6s 16ms/step - loss: 8.0177e-04 - accuracy: 0.9998 - val_loss: 0.1436 - val_accuracy: 0.9913
# Epoch 60/100
# 375/375 [==============================] - 6s 16ms/step - loss: 5.7629e-04 - accuracy: 0.9998 - val_loss: 0.1504 - val_accuracy: 0.9910
# Epoch 61/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1729 - val_accuracy: 0.9907
# Epoch 62/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1575 - val_accuracy: 0.9906
# Epoch 63/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1609 - val_accuracy: 0.9902
# Epoch 64/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1387 - val_accuracy: 0.9910
# Epoch 65/100
# 375/375 [==============================] - 6s 16ms/step - loss: 8.0799e-04 - accuracy: 0.9999 - val_loss: 0.1326 - val_accuracy: 0.9912
# Epoch 66/100
# 375/375 [==============================] - 6s 16ms/step - loss: 6.8176e-04 - accuracy: 0.9998 - val_loss: 0.1336 - val_accuracy: 0.9918
# Epoch 67/100
# 375/375 [==============================] - 6s 16ms/step - loss: 4.9253e-04 - accuracy: 0.9999 - val_loss: 0.1664 - val_accuracy: 0.9908
# Epoch 68/100
# 375/375 [==============================] - 6s 16ms/step - loss: 8.6278e-04 - accuracy: 0.9999 - val_loss: 0.1469 - val_accuracy: 0.9916
# Epoch 69/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1674 - val_accuracy: 0.9905
# Epoch 70/100
# 375/375 [==============================] - 6s 16ms/step - loss: 5.9286e-04 - accuracy: 0.9999 - val_loss: 0.1644 - val_accuracy: 0.9906
# Epoch 71/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1597 - val_accuracy: 0.9898
# Epoch 72/100
# 375/375 [==============================] - 6s 16ms/step - loss: 1.8511e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9916
# Epoch 73/100
# 375/375 [==============================] - 6s 16ms/step - loss: 1.3033e-04 - accuracy: 0.9999 - val_loss: 0.1686 - val_accuracy: 0.9917
# Epoch 74/100
# 375/375 [==============================] - 6s 16ms/step - loss: 9.8694e-04 - accuracy: 0.9998 - val_loss: 0.1812 - val_accuracy: 0.9903
# Epoch 75/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.2108 - val_accuracy: 0.9901
# Epoch 76/100
# 375/375 [==============================] - 6s 15ms/step - loss: 8.2671e-04 - accuracy: 0.9997 - val_loss: 0.1794 - val_accuracy: 0.9911
# Epoch 77/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1658 - val_accuracy: 0.9912
# Epoch 78/100
# 375/375 [==============================] - 6s 16ms/step - loss: 7.1772e-04 - accuracy: 0.9999 - val_loss: 0.1698 - val_accuracy: 0.9910
# Epoch 79/100
# 375/375 [==============================] - 6s 16ms/step - loss: 2.8757e-04 - accuracy: 0.9999 - val_loss: 0.1632 - val_accuracy: 0.9910
# Epoch 80/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1725 - val_accuracy: 0.9916
# Epoch 81/100
# 375/375 [==============================] - 6s 16ms/step - loss: 1.5828e-04 - accuracy: 0.9999 - val_loss: 0.1668 - val_accuracy: 0.9911
# Epoch 82/100
# 375/375 [==============================] - 6s 16ms/step - loss: 1.5490e-04 - accuracy: 0.9999 - val_loss: 0.1709 - val_accuracy: 0.9911
# Epoch 83/100
# 375/375 [==============================] - 6s 16ms/step - loss: 5.1275e-04 - accuracy: 0.9999 - val_loss: 0.2168 - val_accuracy: 0.9908
# Epoch 84/100
# 375/375 [==============================] - 6s 16ms/step - loss: 6.3427e-04 - accuracy: 0.9998 - val_loss: 0.2125 - val_accuracy: 0.9909
# Epoch 85/100
# 375/375 [==============================] - 6s 16ms/step - loss: 9.7725e-04 - accuracy: 0.9998 - val_loss: 0.2120 - val_accuracy: 0.9903
# Epoch 86/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.2139 - val_accuracy: 0.9903
# Epoch 87/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.2010 - val_accuracy: 0.9908
# Epoch 88/100
# 375/375 [==============================] - 6s 16ms/step - loss: 2.0491e-04 - accuracy: 0.9999 - val_loss: 0.1900 - val_accuracy: 0.9907
# Epoch 89/100
# 375/375 [==============================] - 6s 16ms/step - loss: 3.7198e-04 - accuracy: 0.9999 - val_loss: 0.2015 - val_accuracy: 0.9915
# Epoch 90/100
# 375/375 [==============================] - 6s 16ms/step - loss: 2.2946e-04 - accuracy: 0.9999 - val_loss: 0.1981 - val_accuracy: 0.9904
# Epoch 91/100
# 375/375 [==============================] - 6s 16ms/step - loss: 3.5507e-04 - accuracy: 0.9999 - val_loss: 0.2215 - val_accuracy: 0.9909
# Epoch 92/100
# 375/375 [==============================] - 6s 16ms/step - loss: 9.2140e-04 - accuracy: 0.9998 - val_loss: 0.1969 - val_accuracy: 0.9911
# Epoch 93/100
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.1928 - val_accuracy: 0.9911
# Epoch 94/100
# 375/375 [==============================] - 6s 16ms/step - loss: 5.0855e-04 - accuracy: 0.9999 - val_loss: 0.1937 - val_accuracy: 0.9895
# Epoch 95/100
# 375/375 [==============================] - 6s 16ms/step - loss: 8.4564e-04 - accuracy: 0.9999 - val_loss: 0.2020 - val_accuracy: 0.9903
# Epoch 96/100
# 375/375 [==============================] - 6s 16ms/step - loss: 5.1713e-04 - accuracy: 0.9999 - val_loss: 0.1997 - val_accuracy: 0.9911
# Epoch 97/100
# 375/375 [==============================] - 6s 16ms/step - loss: 5.4058e-04 - accuracy: 0.9998 - val_loss: 0.1830 - val_accuracy: 0.9918
# Epoch 98/100
# 375/375 [==============================] - 6s 16ms/step - loss: 7.0566e-04 - accuracy: 0.9998 - val_loss: 0.2249 - val_accuracy: 0.9909
# Epoch 99/100
# 375/375 [==============================] - 6s 16ms/step - loss: 6.9929e-04 - accuracy: 0.9999 - val_loss: 0.2031 - val_accuracy: 0.9916
# Epoch 100/100
# 375/375 [==============================] - 6s 16ms/step - loss: 1.6473e-04 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.9918
# CPU times: user 9min 23s, sys: 38.3 s, total: 10min 1s
# Wall time: 10min 24s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
# plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1221 - accuracy: 0.9938
# Loss = 0.12211
# Accuracy = 0.99380

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
